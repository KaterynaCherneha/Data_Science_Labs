# %% [markdown]
# ## Мій перший Notebook
#
# Jupyter Notebook дозволяє поєднувати звичайний текст, **жирний текст** (наприклад, Python-код) та *курсив* (текстові пояснення).
#
# Основні типи осередків:
# 1. Code
# 2. Markdown
#
# Ось маркований список із фрагментом програмного коду:
# - Команда для виведення тексту: `print("Hello, Jupyter!")`
# - Виконання математичних операцій

# %% [markdown]
# print("Hello, Jupyter!")

# %%
print("Hello, Jupyter!")
# Out:
# Hello, Jupyter!

# %%
student_name = "Kateryna"
group = "MIT-31"

print("Студент:", student_name)
print("Група:", group)
# Out:
# Студент: Kateryna
# Група: MIT-31

# %%
integer_value = 10
float_value = 3.14
text_value = "Data Science"
boolean_value = True

print(integer_value, type(integer_value))
print(float_value, type(float_value))
print(text_value, type(text_value))
print(boolean_value, type(boolean_value))
# Out:
# 10 <class 'int'>
# 3.14 <class 'float'>
# Data Science <class 'str'>
# True <class 'bool'>

# %%
a = 15
b = 4

print("Сума:", a + b)
print("Різниця:", a - b)
print("Добуток:", a * b)
print("Результат ділення:", a / b)
print("Ціла частина від ділення:", a // b)
print("Остача від ділення:", a % b)
print("Піднесення до степеня:", a ** b)
# Out:
# Сума: 19
# Різниця: 11
# Добуток: 60
# Результат ділення: 3.75
# Ціла частина від ділення: 3
# Остача від ділення: 3
# Піднесення до степеня: 50625

# %%
values = [10, 20, 30, 40, 50]

print("Весь список:", values)
print("Перший елемент:", values[0])
print("Останній елемент:", values[-1])
print("Кількість елементів:", len(values))

values.append(60)
print("Після додавання нового елемента:", values)
# Out:
# Весь список: [10, 20, 30, 40, 50]
# Перший елемент: 10
# Останній елемент: 50
# Кількість елементів: 5
# Після додавання нового елемента: [10, 20, 30, 40, 50, 60]

# %%
import sys

print("Python version:")
print(sys.version)

print("\nPython executable:")
print(sys.executable)
# Out:
# Python version:
# 3.10.6 (tags/v3.10.6:9c7b4bd, Aug  1 2022, 21:53:49) [MSC v.1932 64 bit (AMD64)]
#
# Python executable:
# c:\Python310\python.exe

# %% [markdown]
# ## Висновок
# Під час виконання лабораторної роботи було успішно налаштовано середовище розробки на базі VS Code, Python та Git. Віртуальне середовище `.venv` використовується для ізоляції залежностей проєкту, щоб уникнути конфліктів між бібліотеками. Jupyter Notebook дозволяє ефективно поєднувати програмний код (Code cells) із текстовими поясненнями (Markdown cells). Усі обчислення виконуються за допомогою ядра (kernel), яке зберігає стан поточного сеансу, а система Git та сервіс GitHub застосовуються для збереження історії змін та віддаленого доступу до коду
